# %%
import math
import numpy as np
import pandas as pd
import nltk
import matplotlib.pyplot as plt
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import wordnet as wn
from nltk.corpus import stopwords
from owlready2 import *
import seaborn as sns
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Abel
# [nltk_data]     Teklearegay\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Abel
# [nltk_data]     Teklearegay\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Abel
# [nltk_data]     Teklearegay\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %%
def get_path(cl):
    path = cl.name
    while True:
        try:
            path = path + '/' + cl.is_a[0].name
        except IndexError:
            break
        cl = cl.is_a[0]
        if cl == 'owl.Thing':
          #the very first node
            break

    return '/'.join(path.split('/')[::-1])

# %%
path = 'OntoWind.owl'
path2= 'SF-ONT.owl'
def read_ontology(path):
    onto = get_ontology(path)
    onto.load()

    # Read classes
    classes = []

    for cl in onto.classes():
        classes.append(cl)

    classes = list(set(classes))

    '''# Read properties
    properties = []

    for prop in onto.properties():
        properties.append(prop)

    properties = list(set(properties))'''

    return classes
def get_classes_df(ont_path):
    data = []

    # Parse ontologies
    classes1 = read_ontology(ont_path)

    # Generate classes
    for class_ in classes1:
      data.append((class_.name.lower(), class_.is_a[0].name.lower(), 
                     get_path(class_).lower(),''.join(class_.label).lower(),''.join(class_.comment).lower()))
    dataset = pd.DataFrame(data, columns=['Name','Parent','Path','label','comment'])

    return dataset

# %% [markdown]
# # Lexical Measures

# %%
###-----levenshtein-----###

def iterative_levenshtein(s, t, costs=(1, 1, 1)):
    """ 
        iterative_levenshtein(s, t) -> ldist
        ldist is the Levenshtein distance between the strings 
        s and t.
        For all i and j, dist[i,j] will contain the Levenshtein 
        distance between the first i characters of s and the 
        first j characters of t
        
        costs: a tuple or a list with three integers (d, i, s)
               where d defines the costs for a deletion
                     i defines the costs for an insertion and
                     s defines the costs for a substitution

    Taken from python course example at: https://python-course.eu/applications-python/levenshtein-distance.php 
    """

    rows = len(s)+1
    cols = len(t)+1
    deletes, inserts, substitutes = costs
    
    dist = [[0 for x in range(cols)] for x in range(rows)]

    # source prefixes can be transformed into empty strings 
    # by deletions:
    for row in range(1, rows):
        dist[row][0] = row * deletes

    # target prefixes can be created from an empty source string
    # by inserting the characters
    for col in range(1, cols):
        dist[0][col] = col * inserts
        
    for col in range(1, cols):
        for row in range(1, rows):
            if s[row-1] == t[col-1]:
                cost = 0
            else:
                cost = substitutes
            dist[row][col] = min(dist[row-1][col] + deletes,
                                 dist[row][col-1] + inserts,
                                 dist[row-1][col-1] + cost) # substitution

    #for r in range(rows):
        #print(dist[r])
    
 
    return dist[row][col]

# %%
iterative_levenshtein('hello', 'hey', costs=(1, 1, 1))
# Out:
# 3

# %%
def lexicalSimilarity2(e1,e2):
    
    lenght_e1 = len(e1)
    lenght_e2 = len(e2)
    
    ed = iterative_levenshtein(e1,e2)
    alfa = 1/3
    beta = 1/3
    #weights for combining similarity measures: nodes and labels respectively. might consider adding comments
    
    lex_sim = (alfa*(max(lenght_e1,lenght_e2) - ed))/(alfa*(max(lenght_e1,lenght_e2)-ed)
    +(beta*(lenght_e1+lenght_e2-2*max(lenght_e1,lenght_e2)+2*ed)))
    return(lex_sim)

# %%
def parents_lexical_sim(p1_list,p2_list):
  l1 = p1_list
  l2 = p2_list
#3.2.2 on the paper
  n = len(l1)
  m = len(l2)


  n_mat = [n+1-k for k in range(1,n+1)]
  m_mat = [m+1-k for k in range(1,m+1)]

  #Create empty matrix to fill with lex sim of parents
  M_lex = np.zeros((len(l1),len(l2)))

  #Iterate and fill matrix with lex sim of all parents 
  for i in range(len(l1)):
      u = l1[i]
      for j in range(len(l2)):
          v = l2[j]
          # similarity -> Lexical similarity
          M_lex[i,j] = lexicalSimilarity2(u,v)

  d = pd.DataFrame(M_lex,columns=l2,index=l1)
  n_parents = sum(list(d.max(axis=1)*n_mat))/(n*(n+1))
  m_parents = sum(list(i for i in d.max(axis=0)*m_mat))/(m*(m+1))
  
  return (n_parents+m_parents)

# %%
def structural_sim(p1,p2,param):
  a,b = param
  p1_list = p1.split('/')
  p2_list = p2.split('/')

  ci = p1_list[-1]
  cj = p2_list[-1]
  pi = p1_list[:-1]
  pj = p2_list[:-1]

  lex_sim_entity = lexicalSimilarity2(ci,cj)

  lex_sim_parents = parents_lexical_sim(pi,pj)

  struct_sim = (a*lex_sim_entity) + (b*lex_sim_parents)
  return struct_sim

# %%
def struc_similarity_matrix(path1,path2,obj,param):
  df1_ = get_classes_df(path1)
  df2_ = get_classes_df(path2)



  entity_list = df1_['Name'].values
  entity_list2 = df2_['Name'].values

  l1 = df1_['Path'].values
  l2 = df2_['Path'].values


  #Create empty matrix to fill
  M_sim = np.zeros((l1.shape[0],l2.shape[0]))

  #Iterate and fill 
  for i in range(l1.shape[0]):
      u = l1[i]
      for j in range(l2.shape[0]):
          v = l2[j]
          #similarity -> structural similarity 
          M_sim[i,j] = structural_sim(u,v,param)

  DF_sim = pd.DataFrame(M_sim,columns=entity_list2,index=entity_list)

  return DF_sim

# %%
def sim_plot(sim_df,threshold):
  plot_df = sim_df
  plot_df[plot_df<threshold]=0.0
  rows = sim_df.shape[0]
  cols = sim_df.shape[1]

  plt.figure(figsize=((0.4*rows),(0.4*cols)))
  cmap = sns.diverging_palette(230, 20, as_cmap=True)
  cg = sns.heatmap(sim_df, fmt="g", cmap=cmap,linewidths=0.5, linecolor='black')

# %%
sim_df = struc_similarity_matrix(path,path2,'Class',(0.5,0.5))

# %%
sim_plot(sim_df, 0.5)

# %%
path2= 'OntoWind.owl'

onto = get_ontology(path2)
onto.load()

# Read classes
classes = []

for cl in onto.classes():
    classes.append(cl)

classes = list(set(classes))
print(classes)
# Out:
# [OntoWind.TurbineStatus, OntoWind.AROME, OntoWind.PhysicalModel, OntoWind.INCA, OntoWind.CupAnemometer, OntoWind.InternationalWindEnergyAssociation, OntoWind.SolarRadiationSensor, OntoWind.ARX, OntoWind.WindPowerPlant, OntoWind.CommercialWindEnergyCompany, OntoWind.SonicAnemometer, OntoWind.ALARO, OntoWind.InternationalOrganization, OntoWind.ARMA, OntoWind.PressureSensor, OntoWind.WindPowerForecastModel, OntoWind.WindProfiler, OntoWind.Tower, OntoWind.MOS, OntoWind.WindRelatedStructuralComponent, OntoWind.Pressure, OntoWind.VerticalWindComponent, OntoWind.WindRelatedData, OntoWind.WindTurbine, OntoWind.NationalOrganization, OntoWind.Humidity, OntoWind.SODARSensor, OntoWind.OffshoreWindPowerPlant, OntoWind.Sensor, OntoWind.HorizontalWindComponent, OntoWind.SolarRadiation, OntoWind.FaultData, OntoWind.WindDirection, OntoWind.Hub, OntoWind.WindPower, OntoWind.ANFIS, OntoWind.MLP, OntoWind.U-component, OntoWind.Blade, OntoWind.OnshoreWindPowerPlant, OntoWind.HIRLAM, OntoWind.SARIMA, OntoWind.ForecastPower, OntoWind.WindSpeed, OntoWind.IFS, OntoWind.StatisticalModel, OntoWind.Turbulence, OntoWind.ARPS, OntoWind.MeasuredPower, OntoWind.V-axisWindTurbine, OntoWind.Brake, OntoWind.H-axisWindTurbine, OntoWind.MeteorologicalTower, OntoWind.WindRelatedModel, OntoWind.Generator, OntoWind.WindVane, OntoWind.InternationalWeatherOrganization, OntoWind.SVM, OntoWind.ARXM, OntoWind.MM5, OntoWind.WRF, OntoWind.NationalWindEnergyAssociation, OntoWind.WindRelatedOrganization, OntoWind.MinistryOfEnergy, OntoWind.NumericalWeatherPrediction, OntoWind.GovernmentalEnergyOrganization, OntoWind.CommercialWeatherForecastCompany, OntoWind.Temperature, OntoWind.LIDARSensor, OntoWind.TemperatureSensor, OntoWind.Nacelle, OntoWind.Anemometer, OntoWind.V-component, OntoWind.ARIMA, OntoWind.WindData, OntoWind.ALADIN, OntoWind.NationalWeatherService, OntoWind.GFS, OntoWind.RADARSensor, OntoWind.MeteorologicalData, OntoWind.WindShear, OntoWind.ANN, OntoWind.NAM, OntoWind.TransmissionSystemOperator, OntoWind.ARPEGE, OntoWind.PSO, OntoWind.HARMONIE, OntoWind.Gearbox, OntoWind.PropellerAnemometer, OntoWind.HumiditySensor, OntoWind.Rotor, OntoWind.AR, OntoWind.NationalWindResearchOrganization]

# %%
###----Jaccard-----###
def jaccard_similarity(x,y):
  """ returns the jaccard similarity between two lists """
  intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
  union_cardinality = len(set.union(*[set(x), set(y)]))
  return intersection_cardinality/float(union_cardinality)

# %%
def jac_similarity_matrix(path,path2,obj,param):
    df1_ = get_classes_df(path)
    df2_ = get_classes_df(path2)



    entity_list = df1_['Name'].values
    entity_list2 = df2_['Name'].values

    l1 = df1_['Path'].values
    l2 = df2_['Path'].values
    #print(l2)



    #Create empty matrix to fill
    M_sim = np.zeros((l1.shape[0],l2.shape[0]))
    #Iterate and fill 
    for i in range(l1.shape[0]):
      u = entity_list[i]
      for j in range(l2.shape[0]):
          v = entity_list2[j]
          #similarity -> structural similarity 
          M_sim[i,j] = jaccard_similarity(u,v)

    DF_sim = pd.DataFrame(M_sim,columns=entity_list2,index=entity_list)

    return DF_sim

# %%
sim_df_jac = jac_similarity_matrix(path,path2,'Class',(0.5,0.5))

# %%
sim_df_jac
# Out:
#                                   annmodelattributes  projectdevelopers  \
# turbinestatus                               0.692308           0.250000
# arome                                       0.384615           0.230769
# physicalmodel                               0.470588           0.437500
# inca                                        0.214286           0.071429
# cupanemometer                               0.533333           0.400000
# ...                                              ...                ...
# propelleranemometer                         0.571429           0.428571
# humiditysensor                              0.666667           0.352941
# rotor                                       0.230769           0.272727
# ar                                          0.153846           0.083333
# nationalwindresearchorganization            0.555556           0.444444
#
#                                   forecastinputs  biddingstrategy  skewness  \
# turbinestatus                           0.615385         0.666667  0.272727
# arome                                   0.307692         0.230769  0.111111
# physicalmodel                           0.411765         0.352941  0.133333
# inca                                    0.333333         0.250000  0.125000
# cupanemometer                           0.692308         0.312500  0.153846
# ...                                          ...              ...       ...
# propelleranemometer                     0.500000         0.333333  0.166667
# humiditysensor                          0.500000         0.533333  0.214286
# rotor                                   0.250000         0.166667  0.000000
# ar                                      0.166667         0.181818  0.000000
# nationalwindresearchorganization        0.500000         0.529412  0.250000
#
#                                   systemplanning  longtermhorizonendusers  \
# turbinestatus                           0.428571                 0.437500
# arome                                   0.230769                 0.266667
# physicalmodel                           0.533333                 0.444444
# inca                                    0.250000                 0.125000
# cupanemometer                           0.400000                 0.411765
# ...                                          ...                      ...
# propelleranemometer                     0.538462                 0.437500
# humiditysensor                          0.437500                 0.733333
# rotor                                   0.076923                 0.214286
# ar                                      0.083333                 0.066667
# nationalwindresearchorganization        0.444444                 0.705882
#
#                                   atmospheric  annapplications       nwp  ...  \
# turbinestatus                        0.428571         0.384615  0.090909  ...
# arome                                0.454545         0.166667  0.000000  ...
# physicalmodel                        0.642857         0.500000  0.071429  ...
# inca                                 0.250000         0.444444  0.166667  ...
# cupanemometer                        0.615385         0.461538  0.181818  ...
# ...                                       ...              ...       ...  ...
# propelleranemometer                  0.538462         0.500000  0.200000  ...
# humiditysensor                       0.533333         0.312500  0.071429  ...
# rotor                                0.272727         0.200000  0.000000  ...
# ar                                   0.181818         0.100000  0.000000  ...
# nationalwindresearchorganization     0.529412         0.500000  0.125000  ...
#
#                                   modelattributes  pointscale  \
# turbinestatus                            0.615385    0.461538
# arome                                    0.416667    0.250000
# physicalmodel                            0.500000    0.571429
# inca                                     0.142857    0.400000
# cupanemometer                            0.466667    0.538462
# ...                                           ...         ...
# propelleranemometer                      0.500000    0.583333
# humiditysensor                           0.600000    0.375000
# rotor                                    0.250000    0.181818
# ar                                       0.166667    0.090909
# nationalwindresearchorganization         0.500000    0.562500
#
#                                   statisticalmetrics  forecastmetrics  \
# turbinestatus                               0.500000         0.461538
# arome                                       0.400000         0.500000
# physicalmodel                               0.500000         0.466667
# inca                                        0.300000         0.272727
# cupanemometer                               0.461538         0.538462
# ...                                              ...              ...
# propelleranemometer                         0.500000         0.461538
# humiditysensor                              0.400000         0.466667
# rotor                                       0.200000         0.300000
# ar                                          0.222222         0.200000
# nationalwindresearchorganization            0.500000         0.470588
#
#                                   durationdescription  satellitebased  \
# turbinestatus                                0.615385        0.545455
# arome                                        0.307692        0.181818
# physicalmodel                                0.500000        0.428571
# inca                                         0.333333        0.200000
# cupanemometer                                0.692308        0.200000
# ...                                               ...             ...
# propelleranemometer                          0.500000        0.307692
# humiditysensor                               0.600000        0.333333
# rotor                                        0.250000        0.100000
# ar                                           0.166667        0.111111
# nationalwindresearchorganization             0.588235        0.437500
#
#                                       mape       mbe  outagemanagement  \
# turbinestatus                     0.181818  0.200000          0.416667
# arome                             0.500000  0.333333          0.444444
# physicalmodel                     0.333333  0.153846          0.250000
# inca                              0.142857  0.000000          0.200000
# cupanemometer                     0.400000  0.181818          0.636364
# ...                                    ...       ...               ...
# propelleranemometer               0.444444  0.200000          0.545455
# humiditysensor                    0.142857  0.153846          0.428571
# rotor                             0.000000  0.000000          0.222222
# ar                                0.200000  0.000000          0.111111
# nationalwindresearchorganization  0.117647  0.058824          0.352941
#
#                                   geographicdescription
# turbinestatus                                  0.466667
# arome                                          0.285714
# physicalmodel                                  0.562500
# inca                                           0.307692
# cupanemometer                                  0.533333
# ...                                                 ...
# propelleranemometer                            0.466667
# humiditysensor                                 0.562500
# rotor                                          0.230769
# ar                                             0.153846
# nationalwindresearchorganization               0.750000
#
# [93 rows x 96 columns]

# %%
sim_plot(sim_df_jac, 0.5)

# %%
jaccard_similarity('thing/windrelateddata/turbinestatus','thing/modelattributes/annmodelattributes')
# Out:
# 0.8235294117647058
